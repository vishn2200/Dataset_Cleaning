# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/csvel/OneDrive/Desktop/NYPD_Shooting_Incident_Data__Historic_.csv")

# %%
data
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO  PRECINCT  \
# 0          74146165  08/14/2010    3:11:00     QUEENS       113
# 1          66928846  10/17/2009   18:03:00   BROOKLYN        67
# 2          29114164  05/18/2007   23:00:00   BROOKLYN        75
# 3          85180336    06-09-12   17:15:00   BROOKLYN        81
# 4          73405770  06/27/2010    4:14:00      BRONX        47
# ...             ...         ...        ...        ...       ...
# 21621     198255459    06-08-19    5:05:00  MANHATTAN        33
# 21622     202458696  09/13/2019   20:47:00   BROOKLYN        79
# 21623     196195745  04/18/2019   22:30:00  MANHATTAN        23
# 21624     205437642  11/20/2019   23:11:00      BRONX        44
# 21625     193694862  02/17/2019   14:08:00   BROOKLYN        63
#
#        JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                    0.0                        NaN                    False
# ...

# %%
missing_values=data.isna().sum()

# %%
missing_values
# Out:
# INCIDENT_KEY                   0
# OCCUR_DATE                     0
# OCCUR_TIME                     0
# BORO                           0
# PRECINCT                       0
# JURISDICTION_CODE              2
# LOCATION_DESC              12361
# STATISTICAL_MURDER_FLAG        0
# PERP_AGE_GROUP              7305
# PERP_SEX                    7271
# PERP_RACE                   7271
# VIC_AGE_GROUP                  0
# VIC_SEX                        0
# VIC_RACE                       0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                       0
# Longitude                      0
# Lon_Lat                        0
# dtype: int64

# %%
missing_values_percent = data.isna().sum()*100 / len(data)

# %%
missing_values_percent
# Out:
# INCIDENT_KEY                0.000000
# OCCUR_DATE                  0.000000
# OCCUR_TIME                  0.000000
# BORO                        0.000000
# PRECINCT                    0.000000
# JURISDICTION_CODE           0.009248
# LOCATION_DESC              57.158050
# STATISTICAL_MURDER_FLAG     0.000000
# PERP_AGE_GROUP             33.778785
# PERP_SEX                   33.621567
# PERP_RACE                  33.621567
# VIC_AGE_GROUP               0.000000
# VIC_SEX                     0.000000
# VIC_RACE                    0.000000
# X_COORD_CD                  0.000000
# Y_COORD_CD                  0.000000
# Latitude                    0.000000
# Longitude                   0.000000
# Lon_Lat                     0.000000
# dtype: float64

# %%
data['PERP_AGE_GROUP'].mode()
# Out:
# 0    18-24
# Name: PERP_AGE_GROUP, dtype: object

# %%
import numpy as np
data['PERP_AGE_GROUP'] = data['PERP_AGE_GROUP'].replace(np.nan,'18-24')

# %%
data
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO  PRECINCT  \
# 0          74146165  08/14/2010    3:11:00     QUEENS       113
# 1          66928846  10/17/2009   18:03:00   BROOKLYN        67
# 2          29114164  05/18/2007   23:00:00   BROOKLYN        75
# 3          85180336    06-09-12   17:15:00   BROOKLYN        81
# 4          73405770  06/27/2010    4:14:00      BRONX        47
# ...             ...         ...        ...        ...       ...
# 21621     198255459    06-08-19    5:05:00  MANHATTAN        33
# 21622     202458696  09/13/2019   20:47:00   BROOKLYN        79
# 21623     196195745  04/18/2019   22:30:00  MANHATTAN        23
# 21624     205437642  11/20/2019   23:11:00      BRONX        44
# 21625     193694862  02/17/2019   14:08:00   BROOKLYN        63
#
#        JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                    0.0                        NaN                    False
# ...

# %%
data['PERP_AGE_GROUP'] = data['PERP_AGE_GROUP'].replace('UNKNOWN','18-24')

# %%
data
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME       BORO  PRECINCT  \
# 0          74146165  08/14/2010    3:11:00     QUEENS       113
# 1          66928846  10/17/2009   18:03:00   BROOKLYN        67
# 2          29114164  05/18/2007   23:00:00   BROOKLYN        75
# 3          85180336    06-09-12   17:15:00   BROOKLYN        81
# 4          73405770  06/27/2010    4:14:00      BRONX        47
# ...             ...         ...        ...        ...       ...
# 21621     198255459    06-08-19    5:05:00  MANHATTAN        33
# 21622     202458696  09/13/2019   20:47:00   BROOKLYN        79
# 21623     196195745  04/18/2019   22:30:00  MANHATTAN        23
# 21624     205437642  11/20/2019   23:11:00      BRONX        44
# 21625     193694862  02/17/2019   14:08:00   BROOKLYN        63
#
#        JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                    0.0                        NaN                    False
# ...
